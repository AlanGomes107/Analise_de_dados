# %% [markdown]
# <a href="https://colab.research.google.com/github/AlanGomes107/Analise_de_dados/blob/main/Plots_de_distribui%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Plots de distribuições**
# Vamos discutir alguns gráficos que nos permitem visualizar a distribuição de um conjunto de dados. Esses plots são:
#
# distplot (Histograma)
# jointplot (Gráfico de Dispersão)
# pairplot (Histograma e Gráfico de Dispersão para lista de variáveis quantitativas)

# %%
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # **Dados**
# Seaborn vem com conjuntos de dados embutidos.

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # **distplot**
# O distplot mostra a distribuição de um conjunto de observações de uma variável.

# %%
# %matplotlib inline
sns.distplot(tips['total_bill'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Para remover a camada kde e apenas usar o histograma:

# %%
# %matplotlib inline
sns.distplot(tips['total_bill'],kde=False,bins=30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # ***jointplot***
# jointplot() permite combinar basicamente dois distplots() para dados bivariados. Podemos visualizar os dados das seguintes formas (usando o kind):
#
# “scatter”
# “reg”

# %%
# %matplotlib inline
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')

# %%
# %matplotlib inline
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %% [markdown]
# # ***pairplot***
# pairplot irá traçar distribuições entre pares em todo o DataFrame (para as colunas numéricas) e suporta um argumento de matiz de cor (para colunas categóricas).

# %%
# %matplotlib inline
sns.pairplot(tips)

# %%
# %matplotlib inline
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %%
## Fim
